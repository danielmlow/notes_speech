# %%
from __future__ import print_function, division

# %matplotlib inline
import importlib
import thinkdsp
import thinkplot

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import os
import matplotlib.pyplot as plt

importlib.reload(thinkdsp)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# <module 'thinkdsp' from '/Users/danielmlow/Dropbox/notes_speech/thinkdsp.py'>

# %%
# config
path = '/Users/danielmlow/Dropbox/notes_speech/'

# %% [markdown]
# # Extra: Create a signal and play it

# %%
# signal = thinkdsp.TriangleSignal(200)
signal = thinkdsp.GlottalSignal(500, 1.0, offset=0)
# signal = thinkdsp.SinSignal(500, 1.0, offset=0)
duration = signal.period*10
segment = signal.make_wave(duration, framerate=10000)
wave = signal.make_wave(duration=0.5, framerate=10000)
wave.apodize()
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Plot signal

# %%
segment.plot()

# %%
# 
plt.clf()
wave = thinkdsp.read_wave(os.path.join(path, "wave1.wav"))
spectrum = wave.make_spectrum(normalization=None)
wave.apodize()
spectrum.plot()

# %% [markdown]
# # Problem set questions
#
# ## 1.a. Load a signal and observe waveform to classify it:

# %%
# plot wave form
for i in range(1,4):
    plt.clf()
    wave = thinkdsp.read_wave(os.path.join(path, "wave"+str(i)+".wav"))
    thinkplot.config(xlim= [0,0.02], xlabel='Time (seconds)', ylabel='Amplitude')
    wave.plot()
    thinkplot.save(root=os.path.join(path, 'images/waveform_w'+str(i)), formats=['png'])
# Out:
# Writing /Users/danielmlow/Dropbox/notes_speech/images/waveform_w1.png
# Writing /Users/danielmlow/Dropbox/notes_speech/images/waveform_w2.png
# Writing /Users/danielmlow/Dropbox/notes_speech/images/waveform_w3.png

# %% [markdown]
# ## 1.b. What is the periodicity of each waveform?

# %%
# One method is seeing where the vector goes back to the starting y value to get .
[(n*10).round(2) for n in list(wave.ys[:17])] #If on 17, the cycle repeats, on 16 the cycle ends.


#  Another method is doing the spectrum analysis and seeing what the frequency is to then infer the periodicity (see section 1.3.)
# Out:
# [10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  -10.0,
#  -10.0,
#  -10.0,
#  -10.0,
#  -10.0,
#  -10.0,
#  -10.0,
#  -10.0,
#  10.0]

# %%
# plot 2 msec:
for i in range(1,4):
    wave = thinkdsp.read_wave(os.path.join(path,"wave"+str(i)+".wav"))
    thinkplot.config(xlim = [0.040, 0.042], xlabel='Time (seconds)', ylabel='Amplitude ')
    wave.plot()
    thinkplot.save(root=os.path.join(path, 'images/period_w'+str(i)), formats=['png'])
# Out:
# Writing /Users/danielmlow/Dropbox/notes_speech/images/period_w1.png
# Writing /Users/danielmlow/Dropbox/notes_speech/images/period_w2.png
# Writing /Users/danielmlow/Dropbox/notes_speech/images/period_w3.png

# %% [markdown]
# ## Make spectrums

# %%
spectrum = wave.make_spectrum()
spectrum.plot()

for i in range(1,4):
    wave = thinkdsp.read_wave(os.path.join(path,"wave"+str(i)+".wav"))
    thinkplot.config(xlabel='Frequency (Hz)',
                     ylabel='Amplitude')
    spectrum = wave.make_spectrum()
    spectrum.plot()
    thinkplot.save(root=os.path.join(path, 'images/spectrum_w'+str(i)), formats=['png'])
# Out:
# Writing /Users/danielmlow/Dropbox/notes_speech/images/spectrum_w1.png
# Writing /Users/danielmlow/Dropbox/notes_speech/images/spectrum_w2.png
# Writing /Users/danielmlow/Dropbox/notes_speech/images/spectrum_w3.png

# %% [markdown]
# # 4. Downsample

# %%
def sample(wave, factor):
    """Simulates sampling of a wave.
    
    wave: Wave object
    factor: ratio of the new framerate to the original
    """
    ys = np.zeros(len(wave))
    ys[::factor] = wave.ys[::factor]
    return thinkdsp.Wave(ys, framerate=wave.framerate)

# %%
wave = thinkdsp.read_wave(os.path.join(path,"wave3.wav"))
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 4.1. sample every 2

# %%
sampled = sample(wave, 2)
sampled.make_audio()
spectrum = sampled.make_spectrum()
thinkplot.config(xlabel='Frequency (Hz)',
                 ylabel='Amplitude')
spectrum.plot()
thinkplot.save(root=os.path.join(path, 'images/spectrum_w3_subsample_x2'), formats=['png'])
# Out:
# Writing /Users/danielmlow/Dropbox/notes_speech/images/spectrum_w3_subsample_x2.png

# %% [markdown]
# ## 4.2. sample every 10

# %%
sampled = sample(wave, 10)
sampled.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = sampled.make_spectrum()
thinkplot.config(xlabel='Frequency (Hz)',
                 ylabel='Amplitude')
spectrum.plot()
thinkplot.save(root=os.path.join(path, 'images/spectrum_w3_subsample_x10'), formats=['png'])
# Out:
# Writing /Users/danielmlow/Dropbox/notes_speech/images/spectrum_w3_subsample_x10.png
